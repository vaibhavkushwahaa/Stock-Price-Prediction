# %%
from newsapi import NewsApiClient

# %%
newsapi = NewsApiClient(api_key='476a461dcd964f0b8d1da096ebbebd7e')

# %%
    # Fetch the top headlines for the world
top_headlines = newsapi.get_top_headlines(category="technology")

    # Extract the relevant data from the API response
articles = top_headlines['articles']
news_items = []

# %%
for article in articles:
    news_item = {
        'title': article['title'],
        'description': article['description'],
        'url': article['url'],
        'image': article['urlToImage']
    }
    news_items.append(news_item)

# %%
news_items
# Out:
# [{'title': 'IDC: Smartphone Sales Up 7.8 Percent in Q1, Samsung Overtakes Apple - Thurrott.com',
#   'description': 'IDC delivered some good news for the smartphone industry, with sales rising 7.8 percent in the first quarter of 2024 to 289.4 million units.',
#   'url': 'https://www.thurrott.com/mobile/300832/idc-smartphone-sales-up-7-8-percent-in-q1-samsung-overtakes-apple',
#   'image': 'https://thurrott-assets.nyc3.digitaloceanspaces.com/web/wp-content/uploads/sites/2/2024/04/idc-smartphone-q1-2024.jpg'},
#  {'title': "Fallout 4 achievements are all currently broken on Xbox and won't unlock - TrueAchievements",
#   'description': "With Fallout hype hitting fever pitch thanks to the TV show, players have found that the Fallout 4 achievements on Xbox are broken and won't unlock.",
#   'url': 'https://www.trueachievements.com/news/fallout-4-achievements-xbox-broken',
# ...

# %%
<h1 class="title88"><span class="ez-toc-section" id="Powerful_insight_for_professional_investors"></span>Powerful insight for <span class="rotate block" style="opacity: 1; transform: translate(0px, 0px);"><span class="f-blue">every</span> investor.</span><span class="ez-toc-section-end"></span></h1>

# %%
import yfinance as yf

def get_stock_info(stock_symbol):
    # Get the ticker object
    ticker = yf.Ticker(stock_symbol)

    # Get the ticker name (stock symbol)
    ticker_name = stock_symbol

    # Get the company name
    company_name = ticker.info["longName"]

    # Get the exchange name
    exchange_name = ticker.info["exchange"]

    return {
        "ticker_name": ticker_name,
        "company_name": company_name,
        "exchange_name": exchange_name
    }

# Example usage
stock_info = get_stock_info("AAPL")
print(ticker.info)
# Output: {'ticker_name': 'AAPL', 'company_name': 'Apple Inc.', 'exchange_name': 'NMS'}
# Out:
# {'ticker_name': 'AAPL', 'company_name': 'Apple Inc.', 'exchange_name': 'NMS'}

# %%
 # Get the ticker object
ticker = yf.Ticker("AAPL")

# Get the historical market data
exchange_name = ticker.info["exchange"]
print(exchange_name)
# Out:
# NMS

# %%
newsapi = NewsApiClient(api_key='476a461dcd964f0b8d1da096ebbebd7e')
top_headlines = newsapi.get_top_headlines(category="business")

# %%
articles
# Out:
# [{'source': {'id': None, 'name': "Investor's Business Daily"},
#   'author': "Investor's Business Daily",
#   'title': "Dow Jones Futures: Microsoft, Google Jump; New Market Rally Still Must Do This - Investor's Business Daily",
#   'description': "The market rally attempt showed resilience Wednesday amid Meta's sell-off.",
#   'url': 'https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-microsoft-rise-google-soar/',
#   'urlToImage': 'https://www.investors.com/wp-content/uploads/2018/10/stock-bull-night-03-adobe.jpg',
#   'publishedAt': '2024-04-26T05:51:00Z',
#   'content': 'Dow Jones futures rose early Friday, along with S&amp;P 500 futures and especially Nasdaq futures. Microsoft (MSFT) jumped and Google parent Alphabet (GOOGL) soared on earnings, leading another big n… [+8308 chars]'},
#  {'source': {'id': None, 'name': 'Moneycontrol'},
#   'author': 'Moneycontrol News',
# ...

# %%
articles = top_headlines['articles']
news_items = []
for article in articles:
    news_item = {
        'title': article['title'],
        'description': article['description'],
        'url': article['url'],
        'image': article['urlToImage']
    }
    news_items.append(news_item)

news_items
# Out:
# [{'title': "Dow Jones Futures: Microsoft, Google Jump; New Market Rally Still Must Do This - Investor's Business Daily",
#   'description': "The market rally attempt showed resilience Wednesday amid Meta's sell-off.",
#   'url': 'https://www.investors.com/market-trend/stock-market-today/dow-jones-futures-microsoft-rise-google-soar/',
#   'image': 'https://www.investors.com/wp-content/uploads/2018/10/stock-bull-night-03-adobe.jpg'},
#  {'title': 'Blinkit more valuable than Zomato food delivery business: Goldman Sachs - Moneycontrol',
#   'description': 'The $13 billion valuation for Blinkit is an upgrade from Goldman Sachs’ earlier estimate of $8 billion. The upgrades were because of higher gross order value (GOV) estimates, improved industry structure and a larger market potential.',
#   'url': 'https://www.moneycontrol.com/news/technology/blinkit-is-now-larger-than-zomatos-core-business-goldman-sachs-12708703.html',
# ...

# %%
newsapi = NewsApiClient(api_key='476a461dcd964f0b8d1da096ebbebd7e')

    # Fetch the top headlines for the world
top_headlines = newsapi.get_top_headlines(q="world")

# %%
len(top_headlines['articles'])
# Out:
# 7
